# %%
import pandas as pd
import csv
import numpy

read_file = pd.read_csv("Example_haplotype_data_sheet.txt")
read_file.to_csv("Example_haplotype_data_sheet.csv")

import csv
datafile = open("Example_haplotype_data_sheet.csv")
datareader = csv.reader(datafile, delimiter=';')
data = []
#print(datareader)
#for row in datareader:
#    data.append(row)    
#print (data)
#print(pd.read_csv('Example_haplotype_data_sheet.txt'))

#reader = csv.reader(open("Example_haplotype_data_sheet.csv", "rt"), delimiter=",")
#x = list(reader)
#result = numpy.array(x)
#print(result)

#data = list(csv.reader(open("Example_haplotype_data_sheet.csv")))
#print(data)

f = open("Example_haplotype_data_sheet.txt", "r")
count=0
ids=[]
for line in f:
    #count=0
    #for word in line.split():
    #    count+=1
    #    if count==1: 
    count+=1
    if count>1:
        ids+=[line.split()[0]]

locinames = ["CDC1","CDC2","CDC3","CDC4","378_PART_A","378_PART_B","378_PART_C", 
             "X360i2_PART_A","X360i2_PART_B","X360i2_PART_C","X360i2_PART_D", "Junction","MSR_Left","MSR_Right"]

locinames_base = ["CDC1","CDC2","CDC3","CDC4","X378","X360","Junction","MSR"]

ploidy = [2,2,2,2,2,2,2,2,2,2,2,1,1,1]

nids = len(ids)
nloci = len(locinames)
#print(nloci)

# %%
countList=0
wholeList=[]
tempList=[]
data = pd.read_csv('Example_haplotype_data_sheet.txt', sep='\t')
#print(data)
for item in data:
    print(item)
    countList+=1
    #print(list)
    #print(item)
    if countList>1:
        #print(item)
        tempList+=[item]
        #countList+=1
        countString=0
        #if countList==1:
    #    break

#print(tempList)
#print(data)
# Out:
# Seq_ID
# CDC1_Hap_1
# CDC1_Hap_2
# CDC1_Hap_3
# CDC1_Hap_4
# CDC2_Hap_1
# CDC2_Hap_2
# CDC2_Hap_3
# CDC2_Hap_4
# CDC3_Hap_1
# CDC3_Hap_2
# CDC3_Hap_3
# CDC3_Hap_4
# CDC4_Hap_1
# CDC4_Hap_2
# CDC4_Hap_3
# CDC4_Hap_4
# X378_PART_A_Hap_1
# X378_PART_A_Hap_2
# X378_PART_A_Hap_3
# X378_PART_A_Hap_4
# X378_PART_A_Hap_5
# X378_PART_A_Hap_6
# X378_PART_A_Hap_7
# X378_PART_A_Hap_8
# X378_PART_A_Hap_9
# X378_PART_A_Hap_10
# X378_PART_B_Hap_1
# X378_PART_B_Hap_2
# X378_PART_B_Hap_3
# X378_PART_B_Hap_4
# X378_PART_B_Hap_5
# X378_PART_B_Hap_6
# X378_PART_C_Hap_1
# X378_PART_C_Hap_2
# X378_PART_C_Hap_3
# X378_PART_C_Hap_4
# X378_PART_C_Hap_5
# X378_PART_C_Hap_6
# X378_PART_C_Hap_7
# X378_PART_C_Hap_8
# X360i2_PART_A_Hap_1
# X360i2_PART_A_Hap_2
# X360i2_PART_A_Hap_3
# X360i2_PART_A_Hap_4
# X360i2_PART_A_Hap_5
# X360i2_PART_A_Hap_6
# X360i2_PART_B_Hap_1
# X360i2_PART_B_Hap_2
# X360i2_PART_B_Hap_3
# X360i2_PART_B_Hap_4
# X360i2_PART_B_Hap_5
# X360i2_PART_B_Hap_6
# X360i2_PART_B_Hap_7
# X360i2_PART_B_Hap_8
# X360i2_PART_B_Hap_9
# X360i2_PART_B_Hap_10
# X360i2_PART_C_Hap_1
# X360i2_PART_C_Hap_2
# X360i2_PART_C_Hap_3
# X360i2_PART_C_Hap_4
# X360i2_PART_C_Hap_5
# X360i2_PART_C_Hap_6
# X360i2_PART_C_Hap_7
# X360i2_PART_C_Hap_8
# X360i2_PART_D_Hap_1
# X360i2_PART_D_Hap_2
# X360i2_PART_D_Hap_3
# X360i2_PART_D_Hap_4
# X360i2_PART_D_Hap_5
# X360i2_PART_D_Hap_6
# Junction_Hap_1
# Junction_Hap_2
# Junction_Hap_3
# Junction_Hap_4
# Junction_Hap_5
# Junction_Hap_6
# Junction_Hap_7
# Junction_Hap_8
# Junction_Hap_9
# Junction_Hap_10
# Junction_Hap_11
# Junction_Hap_12
# Junction_Hap_13
# Junction_Hap_14
# Junction_Hap_15
# Junction_Hap_16
# Junction_Hap_17
# Junction_Hap_18
# Junction_Hap_19
# Junction_Hap_20
# Junction_Hap_21
# Junction_Hap_22
# Junction_Hap_23
# Junction_Hap_24
# MSR_Left_Hap_1
# MSR_Left_Hap_2
# MSR_Left_Hap_3
# MSR_Left_Hap_4
# MSR_Left_Hap_5
# MSR_Left_Hap_6
# MSR_Left_Hap_7
# MSR_Left_Hap_8
# MSR_Right_Hap_1
# MSR_Right_Hap_2
# MSR_Right_Hap_3
# MSR_Right_Hap_4
# MSR_Right_Hap_5
# MSR_Right_Hap_6
# MSR_Right_Hap_7
# MSR_Right_Hap_8

# %%
#print(tempList)


tempitem=[]
wholeitem=[]
count=0
prev=""
#print(str(tempList))
#for item in tempList:
    #print(item)
    #count+=1
    #print(x)
    #if len(str(tempList))-2>count>12:
        #if x != "\\" and x !="t":
     #   tempitem+=[x]
        #if str(tempList)[count-1]=="t" and str(tempList)[count-2]!="\\":
        #    tempitem+=[x]
        #if x == "\\":
            #print("".join(tempitem))
            #if "".join(tempitem) != ",Seq_ID":
            #    wholeitem+=["".join(tempitem)]
            #    tempitem=[]
        #print(count)
        #if count== len(str(tempList)):
        #    print(str(tempList)[count-1])

#print(len(str(tempList)))
            
#for item in str(tempList).split("\t"):
#    print(item)
templist2=[]
wholelist2=[]
for x in range(nloci):
    for item in tempList:
        if locinames[x] in item:
            templist2+=["True"]
        else:templist2+=["False"]
    wholelist2+=[templist2]
    templist2=[]
    
#print(wholelist2)

# %%
#locinames = ["CDC1","CDC2","CDC3","CDC4","X378_PART_A","X378_PART_B","X378_PART_C", 
#             "X360i2_PART_A","X360i2_PART_B","X360i2_PART_C","X360i2.PART_D", "Junction","MSR_Left","MSR_Right"]
for item2 in locinames:
    print(item2)
# Out:
# CDC1
# CDC2
# CDC3
# CDC4
# 378_PART_A
# 378_PART_B
# 378_PART_C
# X360i2_PART_A
# X360i2_PART_B
# X360i2_PART_C
# X360i2_PART_D
# Junction
# MSR_Left
# MSR_Right

# %%
data = pd.read_csv('Example_haplotype_data_sheet.txt', sep='\t')
#print(data)
templist3=[]
wholelist3=[]
#currentitem="CDC1"
#newitem=""

tempnewList=[]
newList=[]
#print(tempList)
#locinames = ["CDC1","CDC2","CDC3","CDC4","X378_PART_A","X378_PART_B","X378_PART_C", 
#             "X360i2_PART_A","X360i2_PART_B","X360i2_PART_C","X360i2.PART_D", "Junction","MSR_Left","MSR_Right"]
#print(locinames
for item2 in locinames:
    #print(item2)
    for item in tempList:
        #print(item)
        if item2 in item:
            #print(item2)
            #print(data[item])
            #print(len(data[item]))
            tempnewList+=[data[item]]
    #print(tempnewList)
    wholelist3+=[tempnewList]
    tempnewList=[]


#print(wholelist3)
#for item in tempList:
#    for item2 in locinames:
#        if currentitem==item2:
#            newitem=item2
#            if item2 in item:
#                templist3+=[data[item]]
#    if currentitem!=newitem:
#        wholelist3+=[templist3]
#        templist3=[]

tempnum=0
tempmat=[]
wholemat=[]
#print(wholelist3[0][0])
#print(wholelist3[14])
#print(len(wholelist3))
#print(len(wholelist3[0]))
#print(len(wholelist3[0][0]))

#print(wholelist3[0][3])
#print(len(wholelist3))
#print(wholelist3)
for x in range(len(wholelist3)):#whole loci
    #print(x)
    #print(len(wholelist3[x]))
    #print(len(wholelist3[x-1]))
    #if len(wholelist3[x-1]) != 0:
        #if x>0:
           #print(len(wholelist3[x-1][0]))
    for z in range(len(wholelist3[x][0])):# whole rows of loci
        tempnum=0
        for y in range(len(wholelist3[x])):# whole loci sub
            #print(x,y,z)
            #print(wholelist3[x-1][y][z])
            if wholelist3[x][y][z]=="X":
                tempnum+=1
#if x>0:
#    print(tempmat)
#    break
        tempmat+=[tempnum]
        #tempnum=0
    #print(tempmat)
    wholemat+=[tempmat]
    tempmat=[]
            
#print(wholemat)
#print(len(wholemat))

# %%
MaxMoi=[]
Max2=0
for list3 in wholemat:
    #print(item)
    #print(len(item))
    #print(max(list3))
    #break
    if max(list3)>2:
        Max2=max(list3)
    else: Max2=2
    MaxMoi+=[Max2]
    Max2=0
#        if x>2:
 #           Max=x
  #  MaxMoi+=[Max]
   # Max=0

#print(MaxMoi)

MOI=wholemat
#print(MOI)

# %%
nalleles=[]
for x in range(len(wholelist3)):
    nalleles+=[(len(wholelist3[x]))]
    
#print(nalleles)

# %%
#print(wholelist3[0])
#print(wholelist3[0][0])
if "X" in wholelist3[0][0]:
        print("True")

# %%
emptymatrix=[]
newlist=[]
newlist2=[]
for x in range(len(wholelist3)):
    for y in range(len(wholelist3[x])):
        for z in range(len(wholelist3[x][y])):
        #print(wholelist3[x])
        #print(wholelist3[x][y])
        #for y in range(len(wholelist3[x][y])):   
            newlist+=[wholelist3[x][y][z]]
        if "X" in newlist:
            #for l in range(len(newlist)):
            #    newlist3+=[None]
            newlist2+=[newlist]
            newlist=[]
            #newlist3=[]
    emptymatrix+=[newlist2]
    newlist2=[]
            
#print(emptymatrix[0])

#print(len(emptymatrix[9]))

newlist3=[]
emptymatrix2=[]
for x in range(len(wholelist3)):
    for y in range(len(wholelist3[x])):
        count=0
        for z in range(len(wholelist3[x][y])):
            #print(wholelist3[x][y][z])
            count+=1
            if wholelist3[x][y][z]=="X":
                newlist3+=["Hap_"+str(y+1)]
            else:newlist3+=[None]
            if count==98:
                emptymatrix2+=[newlist3]
                newlist3=[]
                

print(emptymatrix2[0])
print(len(emptymatrix2))
# Out:
# ['Hap_1', None, None, None, None, None, None, None, None, None, None, None, None, None, 'Hap_1', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'Hap_1', None, 'Hap_1', None, None, None, None, None, 'Hap_1', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# 110

# %%
ploidy = [2,2,2,2,2,2,2,2,2,2,2,1,1,1]

newlist4=[]
emptymatrix3=[]
currenty=0
#print(len(wholelist3))
for x in range(len(wholelist3)):#whole loci
    #print(x)
    if ploidy[x]>1:
    #print(len(wholelist3[x]))
    #print(len(wholelist3[x-1]))
    #if len(wholelist3[x-1]) != 0:
        #if x>0:
           #print(len(wholelist3[x-1][0]))
        for z in range(len(wholelist3[x][0])):# whole rows of loci
            tempnum=0
            for y in range(len(wholelist3[x])):# whole loci sub
                #print(x,y,z)
                #print(wholelist3[x-1][y][z])
                if wholelist3[x][y][z]=="X":
                    tempnum+=1
                    currenty=y
            if tempnum==1:
                newlist4+=["Hap_"+str(currenty+1)]
            else:newlist4+=[None]
        emptymatrix3+=[newlist4]
        newlist4=[]

#print(emptymatrix3[0])
#print(len(emptymatrix3[0]))
#print(len(emptymatrix3))
# Out:
# ['Hap_1', None, None, None, None, None, None, None, 'Hap_2', None, None, None, None, 'Hap_2', 'Hap_1', 'Hap_2', None, None, None, None, 'Hap_2', None, None, None, None, None, 'Hap_2', None, None, 'Hap_2', 'Hap_1', 'Hap_2', 'Hap_1', 'Hap_2', None, 'Hap_2', 'Hap_2', None, 'Hap_1', None, 'Hap_2', 'Hap_2', None, 'Hap_2', 'Hap_2', 'Hap_2', 'Hap_2', None, 'Hap_2', None, None, 'Hap_2', 'Hap_2', None, 'Hap_2', 'Hap_2', None, None, 'Hap_2', 'Hap_2', 'Hap_2', None, 'Hap_2', 'Hap_2', None, 'Hap_2', 'Hap_2', 'Hap_2', None, 'Hap_2', 'Hap_2', 'Hap_2', None, None, None, None, None, None, 'Hap_2', None, None, 'Hap_2', 'Hap_2', 'Hap_2', None, 'Hap_2', None, None, None, None, 'Hap_2', None, None, None, None, None, None, 'Hap_2']
# 98
# 11

# %%
tempMax=[]
Newdata=[]
print(MaxMoi)
for x in range(len(locinames)):
    for y in range(MaxMoi[x]):
        tempMax+=[str(y+1)+"_Hap_"+str(locinames[x])]
    Newdata+=tempMax
    tempMax=[]

print(Newdata)
# Out:
# [2, 2, 2, 2, 3, 2, 3, 2, 4, 2, 2, 2, 2, 2]
# ['1_Hap_CDC1', '2_Hap_CDC1', '1_Hap_CDC2', '2_Hap_CDC2', '1_Hap_CDC3', '2_Hap_CDC3', '1_Hap_CDC4', '2_Hap_CDC4', '1_Hap_378_PART_A', '2_Hap_378_PART_A', '3_Hap_378_PART_A', '1_Hap_378_PART_B', '2_Hap_378_PART_B', '1_Hap_378_PART_C', '2_Hap_378_PART_C', '3_Hap_378_PART_C', '1_Hap_X360i2_PART_A', '2_Hap_X360i2_PART_A', '1_Hap_X360i2_PART_B', '2_Hap_X360i2_PART_B', '3_Hap_X360i2_PART_B', '4_Hap_X360i2_PART_B', '1_Hap_X360i2_PART_C', '2_Hap_X360i2_PART_C', '1_Hap_X360i2_PART_D', '2_Hap_X360i2_PART_D', '1_Hap_Junction', '2_Hap_Junction', '1_Hap_MSR_Left', '2_Hap_MSR_Left', '1_Hap_MSR_Right', '2_Hap_MSR_Right']

# %%
tempylist=[]
for y in range(len(Newdata)):
    count=0
    for x in range(len(emptymatrix2)):
        count+=1
        for z in range(14):
            for k in range(MaxMoi[z]):
                if count<k:
                    tempylist+=[emptymatrix2[k]]
                    d={Newdata[y]:tempylist}
                    tempylist=[]
                else:break

print(d)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-48-1b34c33d46ce> in <module>
#       4     for x in range(len(emptymatrix2)):
#       5         count+=1
# ----> 6         for k in range(MaxMoi[x]):
#       7             if count<k:
#       8                 tempylist+=[emptymatrix2[k]]
#
# IndexError: list index out of range

# %%
99//98
# Out:
# 1
